# %% [markdown]
# # Alfido Tech Customer Segmentation Analysis
#
# RFM analysis, customer segmentation, purchase trends, and churn risk analysis.

# %%
import pandas as pd

df = pd.read_csv(r'/mnt/data/customer_analysis/ecommerce_customer_data_large.csv')
df.head()
