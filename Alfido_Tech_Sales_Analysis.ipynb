# %% [markdown]
# # Alfido Tech Sales Analysis
#
# ## Objectives
# - Analyze sales across regions, categories, and time.
# - Identify best and worst performing products.
# - Study seasonality patterns.
# - Generate actionable recommendations.
#
# ## KPI Summary
# - Revenue: $2,261,536.78
# - Average Order Value: $459.48
# - Total Orders: 4922
# - Total Customers: 793

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"/mnt/data/extracted/superstore_final_dataset (1).csv", encoding='latin1')
df.head()
