# %% [markdown]
# # Alfido Tech Website Traffic Analysis
#
# ## Objectives
# - Parse and clean traffic log data
# - Analyze user sessions and behavior
# - Measure bounce rate and session duration
# - Identify top landing and exit pages
# - Recommend conversion improvements
#
# ## Dataset
# /mnt/data/web_logs/traffic.csv

# %%
import pandas as pd

df = pd.read_csv(r"/mnt/data/web_logs/traffic.csv", encoding='latin1')
df.head()
